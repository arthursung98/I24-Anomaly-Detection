# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import main
from Graph import Graph
from Node import Node
from Edge import Edge
import plot_graph

# %%
input_directory = r"C:\I24 Motion Project\Anomaly Detection\csv\TM_1000_GT.csv"
df = main.read_full_data(input_directory, 0)

# %%
MyGraph = Graph()

one_frame_df = df.loc[(df['Frame #'] == 70)].sort_values('x').reset_index()
print(one_frame_df)
one_frame_matrix = np.array(one_frame_df)

# Add all the nodes
for one_row in one_frame_matrix :
    ID, x_pos, y_pos = one_row[2], one_row[3], one_row[4]
    car_node = Node(ID,x_pos,y_pos,0)
#     print(car_node.get_attributes())
    MyGraph.add_node(car_node)
    
print(MyGraph.get_nodes())
# Add all the edges thru sliding window approach
# def add_edges(one_frame_df, MyGraph) :

# i = 0

# while(len(one_frame_df) != 0) :
#     # 1. Prepare ego car node to create edges with.
#     ego_car_node = Node(one_frame_df.at[i, 'ID'], 
#                         one_frame_df.at[i, 'x'], 
#                         one_frame_df.at[i, 'y'], 
#                         0)
#     window_start = one_frame_df.at[i, 'x']                              # 2. Get x position of left-most car
#     window_df = one_frame_df.loc[one_frame_df['x'] < window_start + 20] # 3. Select all cars within window
#     # 4. Translate all cars in window as edges and add to graph.
#     window_ar = np.array(window_df)
    
#     for row in window_ar :
#         ID, x_pos, y_pos = row[2], one_row[3], one_row[4]
#         car_node = Node(ID, x_pos, y_pos, 0)
#         edge1, edge2 = Edge(ego_car_node, car_node), Edge(car_node, ego_car_node)
#         print(edge1)
#         MyGraph.add_edge(edge1)
#         MyGraph.add_edge(edge2)
    
#     # 5. Drop the very first row.
#     one_frame_df.drop(index=i,inplace=True)
#     i += 1
# Out:
#    index  Frame #   ID            x          y      speed  acceleration
# 0    240       70  1.0  2315.426725   5.486132  29.061262 -3.623768e-12
# 1    241       70  2.0  2323.694808   9.143554  30.622778  3.047851e-03
# 2    243       70  4.0  2339.547059  12.800975  35.077720  2.743066e-02
# 3    242       70  3.0  2341.546353   1.828711  31.325815  0.000000e+00
# 4    244       70  5.0  2365.705080   9.143554  30.695520 -3.474550e-02
# 5    245       70  6.0  2375.771868   5.486132  30.703038  1.149040e+00
# [<Node.Node object at 0x0000017C864052E0>, <Node.Node object at 0x0000017C86405970>, <Node.Node object at 0x0000017C89803AC0>, <Node.Node object at 0x0000017C8980E3D0>, <Node.Node object at 0x0000017C8980E130>, <Node.Node object at 0x0000017C8980E550>]

# %%
# %matplotlib notebook
##### TODO : Add the == operator for the Graph class, and more checking schemes.
plot_graph.plot_graph(MyGraph)
# plot_graph.test_run_zi()
# Out:
# [(<Node.Node object at 0x0000017C864052E0>, {'ID': 70.0, 'x_position': 1.0, 'y_position': 2315.4267245758406}), (<Node.Node object at 0x0000017C86405970>, {'ID': 70.0, 'x_position': 2.0, 'y_position': 2323.6948084933447}), (<Node.Node object at 0x0000017C89803AC0>, {'ID': 70.0, 'x_position': 4.0, 'y_position': 2339.5470588235303}), (<Node.Node object at 0x0000017C8980E3D0>, {'ID': 70.0, 'x_position': 3.0, 'y_position': 2341.5463527379884}), (<Node.Node object at 0x0000017C8980E130>, {'ID': 70.0, 'x_position': 5.0, 'y_position': 2365.7050797521088}), (<Node.Node object at 0x0000017C8980E550>, {'ID': 70.0, 'x_position': 6.0, 'y_position': 2375.771868332828})]
# <img src="data:image/png;base64,..." width="862.9630239248646">
# Pos :  {<Node.Node object at 0x0000017C864052E0>: array([0., 0.])}
# [(<Node.Node object at 0x0000017C8AA84130>, {'ID': 0, 'x_position': 34.92526027862537, 'y_position': 162.35008896214694}), (<Node.Node object at 0x0000017C8AA87550>, {'ID': 1, 'x_position': 94.25552609886772, 'y_position': 5.796879900663643}), (<Node.Node object at 0x0000017C8A853CA0>, {'ID': 2, 'x_position': 46.86066113123386, 'y_position': 8.096972289685244}), (<Node.Node object at 0x0000017C8A853D00>, {'ID': 3, 'x_position': 188.1431876769968, 'y_position': 145.95347333465958}), (<Node.Node object at 0x0000017C8A853D60>, {'ID': 4, 'x_position': 195.0502942497604, 'y_position': 23.657383413773836}), (<Node.Node object at 0x0000017C8A853DC0>, {'ID': 5, 'x_position': 33.40661873612372, 'y_position': 134.67149024660245}), (<Node.Node object at 0x0000017C8A853E20>, {'ID': 6, 'x_position': 0.9412470669610595, 'y_position': 46.022951101404416}), (<Node.Node object at 0x0000017C8A853E80>, {'ID': 7, 'x_position': 93.32256458327434, 'y_position': 87.38426384625271}), (<Node.Node object at 0x0000017C8A853EE0>, {'ID': 8, 'x_position': 115.59746725233013, 'y_position': 122.52374464069082}), (<Node.Node object at 0x0000017C8A853F40>, {'ID': 9, 'x_position': 160.63471616947197, 'y_position': 84.36457242375745})]
# <img src="data:image/png;base64,..." width="862.9630239248646">
# Pos :  {<Node.Node object at 0x0000017C8AA84130>: array([-0.02393374,  0.58677087]), <Node.Node object at 0x0000017C8AA87550>: array([0.91455241, 0.16826097]), <Node.Node object at 0x0000017C8A853CA0>: array([ 0.27647616, -1.        ]), <Node.Node object at 0x0000017C8A853D00>: array([ 0.11102466, -0.28581662]), <Node.Node object at 0x0000017C8A853D60>: array([-0.32083547,  0.00596414]), <Node.Node object at 0x0000017C8A853DC0>: array([0.52129386, 0.40315198]), <Node.Node object at 0x0000017C8A853E20>: array([-0.5893044 , -0.36781591]), <Node.Node object at 0x0000017C8A853E80>: array([-0.8178437 ,  0.80015902]), <Node.Node object at 0x0000017C8A853EE0>: array([-0.94662131,  0.14747667]), <Node.Node object at 0x0000017C8A853F40>: array([ 0.87519152, -0.45815113])}
